# %%
import os

from importlib import reload  as r
import auxiliaryDataFunctions as dataplot
r(dataplot)
# Out:
# <module 'auxiliaryDataFunctions' from '/home/sebas/GitHub/Masterscriptie/current/finalExperiments/python/auxiliaryDataFunctions.py'>

# %%
r(dataplot)
folderPath = "../data/results/doubleDegreeAllNight"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (secondes)",)
dataplot.folderSinglePlot(folderPath)

# %%
r(dataplot)
folderPath = "../data/results/allNightOnlyFast"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (secondes)",)
dataplot.folderSinglePlot(folderPath)

# %%
r(dataplot)
folderPath = "../data/results/allNightHeurNew"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (secondes)",)
dataplot.folderSinglePlot(folderPath)

# %%
r(dataplot)
folderPath = "../data/results/doubleDegreeAllNightHeuristicTotal"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (secondes)",)
dataplot.folderSinglePlot(folderPath)

# %%
r(dataplot)
folderPath = "../data/results/allNightVariableEdges"
xColumn = "nrEdges"
xLabel = "Number of Edges"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (secondes)", xColumn=xColumn,xLabel=xLabel,yScaleLog=False)
dataplot.folderSinglePlot(folderPath,xColumn=xColumn,xLabel=xLabel)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("../data/results/allNightVariableEdges/greedySinglePathsUni.txt")

plt.hist(df["nrEdges"],bins =20)
plt.show()

# %%
r(dataplot)
folderPath = "../data/results/doubleDegreeAllNightHeuristicTotal"

dataplot.folderSinglePlot(folderPath,yColumn="timeElapsed",yLabel="Elapsed Time (seconds)",splitLayers=True,yScaleLog=True)

# %%
r(dataplot)
folderPath = "../data/results/allNightVariableEdgesNew"
xColumn = "nrEdges"
xLabel = "Number of Edges"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (seconds)", xColumn=xColumn,xLabel=xLabel,yScaleLog=False)
dataplot.folderSinglePlot(folderPath,xColumn=xColumn,xLabel=xLabel)

# %%
df = pd.read_csv("../data/results/allNightVariableEdgesNew/greedySinglePathsUni.txt")

plt.hist(df["nrEdges"],bins =20)
plt.show()

# %%
r(dataplot)
folderPath = "../data/results/allNightVariableNodes"
xColumn = "nrNodes"
xLabel = "Number of Nodes"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (seconds)", xColumn=xColumn,xLabel=xLabel,yScaleLog=False)
dataplot.folderSinglePlot(folderPath,xColumn=xColumn,xLabel=xLabel)

# %%
r(dataplot)
folderPath = "../data/results/allNightVariableLayers"
xColumn = "nrLayers"
xLabel = "Number of Layers"

dataplot.folderSinglePlot(folderPath,yColumn = "timeElapsed", yLabel="Time Elapsed (seconds)", xColumn=xColumn,xLabel=xLabel, nrBins = 21, yScaleLog=False)
dataplot.folderSinglePlot(folderPath,xColumn=xColumn,xLabel=xLabel,nrBins=21)
