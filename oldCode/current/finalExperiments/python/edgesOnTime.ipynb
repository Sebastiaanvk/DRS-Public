# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from importlib import reload  as r
import auxiliaryDataFunctions as dataplot

# %%
dfGPUniMedEdge = pd.read_csv("../data/results/edgesUniformMedium/greedyPeelingUni.txt")
dfGPBiMedEdge = pd.read_csv("../data/results/edgesUniformMedium/greedyPeelingBi.txt")
dfGSPUniMedEdge = pd.read_csv("../data/results/edgesUniformMedium/greedySinglePathsUni.txt")
dfGSPBiMedEdge = pd.read_csv("../data/results/edgesUniformMedium/greedySinglePathsBi.txt")

# %%
r(dataplot)
dataplot.lineplotTimeEdgesSmoother(dfGSPUniMedEdge, plotTitle="Time vs. Number of Edges of GSP algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGPUniMedEdge, plotTitle="Time vs. Number of Edges of GP algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGSPBiMedEdge, plotTitle="Time  vs. Number of Edges of GSPB algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGPBiMedEdge, plotTitle="Time vs. Number of Edges of GPB algorithm", withHue=False)

# %%
dfGPUniMiniEdge = pd.read_csv("../data/results/edgesUniformMini/greedyPeelingUni.txt")
dfGPBiMiniEdge = pd.read_csv("../data/results/edgesUniformMini/greedyPeelingBi.txt")
dfGSPUniMiniEdge = pd.read_csv("../data/results/edgesUniformMini/greedySinglePathsUni.txt")
dfGSPBiMiniEdge = pd.read_csv("../data/results/edgesUniformMini/greedySinglePathsBi.txt")

# %%
r(dataplot)
dataplot.lineplotTimeEdgesSmoother(dfGSPUniMiniEdge, plotTitle="Time vs. Number of Edges of GSP algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGPUniMiniEdge, plotTitle="Time vs. Number of Edges of GP algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGSPBiMiniEdge, plotTitle="Time  vs. Number of Edges of GSPB algorithm", withHue=False)
dataplot.lineplotTimeEdgesSmoother(dfGPBiMiniEdge, plotTitle="Time vs. Number of Edges of GPB algorithm", withHue=False)
